# %% [markdown]
# ---
# title: "About"
# ---

# %% [markdown]
# # Header 1
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Consectetur adipiscing elit ut aliquam purus. Lacinia at quis risus sed vulputate odio ut enim blandit. Dui vivamus arcu felis bibendum ut tristique. Malesuada fames ac turpis egestas maecenas pharetra convallis. Urna molestie at elementum eu facilisis sed odio morbi quis. A diam sollicitudin tempor id eu nisl nunc. Vitae aliquet nec ullamcorper sit amet risus nullam. Egestas pretium aenean pharetra magna. Euismod in pellentesque massa placerat duis ultricies lacus sed.

# %% [markdown]
# # Header 2
#
# My plot:

# %%
import matplotlib.pyplot as plt

x = [5,10,15]

y = [3,6,9]
  
plt.plot(x, y)
  
plt.xlabel('stress')

plt.ylabel('anxiety')
  
plt.title('Emotions')
  
plt.show()

# %% [markdown]
# # Header 3
#
# Felis donec et odio pellentesque diam volutpat commodo sed egestas. Gravida in fermentum et sollicitudin. Et leo duis ut diam. Mauris nunc congue nisi vitae suscipit. Magna sit amet purus gravida quis blandit turpis cursus. Dui sapien eget mi proin sed libero. Risus commodo viverra maecenas accumsan lacus vel. Viverra aliquet eget sit amet tellus cras adipiscing. Nunc mattis enim ut tellus elementum sagittis vitae et. Amet luctus venenatis lectus magna fringilla urna porttitor rhoncus dolor.
