# %% [markdown]
# ---
# title: "Sam's Slides"
# format:
#   revealjs:
#     transition: slide
#     transition-speed: fast
#     slide-number: c/t
#     width: 1600
#     height: 900
#     css: ["theme/theme.css"]
#     theme: simple
#     echo: false
#     bibliography: ../reference.bib
# ---
#
# ## Charlie
# ![Charlie is a morkie](images/charlie.png)
#
# ## Rocky
# ![Rocky is a pitbull mix](images/rocky.png)
#
# ## Plot

# %% [markdown]
# "We predict how the dog acts in the visual world in re- sponse to various situations." (see @ehsani2018let)

# %%
import matplotlib.pyplot as plt

x = [5,10,15]

y = [3,6,9]
  
plt.plot(x, y)
  
plt.xlabel("Charlie's Irritability")

plt.ylabel("Rocky's Energy")
  
plt.title('Dog Dynamic')

plt.show()
